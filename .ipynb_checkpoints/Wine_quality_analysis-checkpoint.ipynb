# %% [markdown]
# # Wine quality

# %% [markdown]
# ## Red analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#saving the dataset in a dataframe 'red_dataset'
red_dataset = pd.read_csv(r'C:\Users\giovanni\Desktop\datasets\wine_quality\winequality-red.csv', sep=';')
red_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## Defining functions

# %%
#function that acquires the outliers over a set treshold from data given
#https://medium.datadriveninvestor.com/finding-outliers-in-dataset-using-python-efc3fce6ce32
def detect_outliers(data):
    outliers = []
    threshold=3
    mean = np.mean(data)
    std =np.std(data)
    for y in data:
        z_score= (y - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
#function that takes the dataset and returns a summary table with descriptive statistics
def summary_table(dataset):
    mean = []
    median = []
    variance = []
    std_dev = []
    outliers_number = []
    outliers_values = []
    data = []
    for column in list(dataset):
        mean.append(np.nanmean(dataset[column][:]))
        median.append(np.nanmedian(dataset[column][:]))
        variance.append(np.nanvar(dataset[column][:]))
        std_dev.append(np.nanstd(dataset[column][:]))
        outliers_number.append(len(detect_outliers(dataset[column][:])))
        outliers_values.append(detect_outliers(dataset[column][:]))
    dataset_dic = {}
    dataset_dic['mean'] = mean
    dataset_dic['median'] = median
    dataset_dic['variance'] = variance
    dataset_dic['standard_deviation'] = std_dev
    dataset_dic['outliers_number'] = outliers_number
    dataset_dic['outliers_values'] = outliers_values
    summary_dataframe = pd.DataFrame(dataset_dic)
    summary_dataframe.index = list(dataset)
    return summary_dataframe

# %%
#removing outliers
def remove_outs(dataset):
    list_of_outliers = [detect_outliers(dataset[column][:]) for column in list(dataset)] #getting the list of outliers
    list_of_outliers = [item for sublist in list_of_outliers for item in sublist] #flattening the list of outliers
    list_of_out_indexes = []
    for indx in dataset.index.values: 
        for item in dataset.loc[indx]:
            if item in list_of_outliers: #checking the items of the row if they are in the list of outliers
                list_of_out_indexes.append(indx) #and the index is added to the list of indexes that do not contain outliers
    not_out_dataset = dataset.drop(list_of_out_indexes) #dropping all indexes
    return not_out_dataset

# %%
#replacing outliers for None values stackoverflow
#I don't want to do that for the quality column 
def replace_outliers(df):
    new_df = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']] #slicing df not to include the last column
    v = new_df.values
    mask = np.abs((v - v.mean(0)) / v.std(0)) > 3 #using a mask for values over a set treshold
    temp = df['quality']#temporarily storing the quality column
    df = df.drop(['quality'], axis=1)
    clean = pd.DataFrame(np.where(mask, np.nan, v), df.index, df.columns)
    clean['quality'] = temp #restoring quality unmodified
    return clean

# %% [markdown]
# ## Exploratory analysis

# %%
red_dataset.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
#replacing outliers with nan values. Keeping the "quality" column unaltered
red_dataset_nout = replace_outliers(red_dataset)
red_dataset_nout
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#creating a summary datafram from the dataset (with outliers)
summary_dataset = summary_table(red_dataset)
summary_dataset
# Out:
#                            mean    median     variance  standard_deviation  \
# fixed acidity          8.319637   7.90000     3.029521            1.740552
# volatile acidity       0.527821   0.52000     0.032042            0.179004
# citric acid            0.270976   0.26000     0.037924            0.194740
# residual sugar         2.538806   2.20000     1.986654            1.409487
# chlorides              0.087467   0.07900     0.002214            0.047051
# free sulfur dioxide   15.874922  14.00000   109.346457           10.456886
# total sulfur dioxide  46.467792  38.00000  1081.425636           32.885037
# density                0.996747   0.99675     0.000004            0.001887
# pH                     3.311113   3.31000     0.023820            0.154338
# sulphates              0.658149   0.62000     0.028715            0.169454
# alcohol               10.422983  10.20000     1.134937            1.065334
# quality                5.636023   6.00000     0.651761            0.807317
#
#                       outliers_number  \
# fixed acidity                      12
# volatile acidity                   10
# citric acid                         1
# residual sugar                     30
# chlorides                          31
# free sulfur dioxide                22
# total sulfur dioxide               15
# density                            18
# pH                                  8
# sulphates                          27
# alcohol                             8
# quality                            10
#
#                                                         outliers_values
# fixed acidity         [15.0, 15.0, 13.8, 14.0, 13.7, 13.7, 15.6, 14....
# volatile acidity      [1.13, 1.07, 1.33, 1.33, 1.09, 1.24, 1.185, 1....
# citric acid                                                       [1.0]
# residual sugar        [10.7, 7.3, 7.2, 7.0, 11.0, 11.0, 7.9, 7.9, 15...
# chlorides             [0.368, 0.341, 0.332, 0.46399999999999997, 0.4...
# free sulfur dioxide   [52.0, 51.0, 50.0, 68.0, 68.0, 54.0, 53.0, 52....
# total sulfur dioxide  [148.0, 153.0, 165.0, 151.0, 149.0, 147.0, 148...
# density               [1.0032, 1.0026, 1.00315, 1.00315, 1.00315, 1....
# pH                       [3.9, 3.85, 2.74, 3.9, 3.78, 3.78, 4.01, 4.01]
# sulphates             [1.56, 1.28, 1.2, 1.28, 1.95, 1.22, 1.95, 1.98...
# alcohol                [14.0, 14.0, 14.0, 14.0, 14.9, 14.0, 14.0, 14.0]
# quality                                  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
#creating a summary datafram from the dataset (without outliers)
summary_dataset_nout = summary_table(red_dataset_nout)
summary_dataset_nout
# Out:
#                            mean    median    variance  standard_deviation  \
# fixed acidity          8.270636   7.90000    2.727531            1.651524
# volatile acidity       0.523433   0.52000    0.029030            0.170383
# citric acid            0.270519   0.26000    0.037615            0.193945
# residual sugar         2.395953   2.20000    0.789504            0.888540
# chlorides              0.081993   0.07900    0.000528            0.022974
# free sulfur dioxide   15.335447  13.00000   89.028249            9.435478
# total sulfur dioxide  45.304293  37.00000  928.104060           30.464800
# density                0.996731   0.99674    0.000003            0.001775
# pH                     3.308925   3.31000    0.022221            0.149068
# sulphates              0.645312   0.62000    0.018172            0.134803
# alcohol               10.404431  10.10000    1.071407            1.035088
# quality                5.636023   6.00000    0.651761            0.807317
#
#                       outliers_number  \
# fixed acidity                       5
# volatile acidity                    4
# citric acid                         0
# residual sugar                     54
# chlorides                          38
# free sulfur dioxide                 5
# total sulfur dioxide               14
# density                             5
# pH                                  1
# sulphates                          23
# alcohol                             5
# quality                            10
#
#                                                         outliers_values
# fixed acidity                            [13.3, 13.4, 13.5, 13.3, 13.3]
# volatile acidity                              [1.04, 1.04, 1.035, 1.04]
# citric acid                                                          []
# residual sugar        [6.1, 6.1, 5.5, 5.9, 5.9, 5.1, 5.5, 5.5, 5.5, ...
# chlorides             [0.17600000000000002, 0.17, 0.172, 0.178000000...
# free sulfur dioxide                      [47.0, 46.0, 45.0, 45.0, 45.0]
# total sulfur dioxide  [145.0, 140.0, 141.0, 143.0, 144.0, 145.0, 144...
# density                        [0.9912, 1.0022, 1.0022, 1.0021, 1.0021]
# pH                                                               [2.86]
# sulphates             [1.08, 1.12, 1.14, 1.08, 1.09, 1.08, 1.13, 1.1...
# alcohol                    [13.6, 13.6, 13.6, 13.566666666666698, 13.6]
# quality                                  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
#lista_colonne = list(red_dataset_nout) #plotting each column
#plt.figure(figsize=(20,10))
#red_dataset_nout.boxplot(column = lista_colonne[0:11], vert=False, fontsize=20)
#plt.show()
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.boxplot(data=red_dataset, orient="h", palette="Set2", ax=ax)
plt.savefig(r'C:\Users\giovanni\Desktop\datasets\wine_quality\plots\boxplots_red')

# %%
fig2, ax2 = plt.subplots()
fig2.set_size_inches(11.7, 8.27)
sns.boxplot(data=red_dataset_nout, orient="h", palette="Set2", ax=ax2)
plt.savefig(r'C:\Users\giovanni\Desktop\datasets\wine_quality\plots\boxplots_red_nout')

# %%
from scipy.stats import norm
#Plot the distribution with a histogram and maximum likelihood gaussian distribution fit
lista_colonne = list(red_dataset_nout)
for c in lista_colonne:
    plt.figure(figsize=(20,10))
    sns.distplot(red_dataset_nout[c], color='crimson')
    plt.savefig(r'C:\Users\giovanni\Desktop\datasets\wine_quality\plots\red_'+c)

# %%
sns.set(style="whitegrid")
sns.color_palette("pastel")
for c in lista_colonne:
    plt.figure(figsize=(20,10))
    sns.boxplot(x=red_dataset_nout[c], color='crimson', linewidth=3.5, medianprops=dict(color="black", alpha=1.0))
    plt.savefig(r'C:\Users\giovanni\Desktop\datasets\wine_quality\plots\boxplot_red_'+c)

# %%
red_dataset_corr = red_dataset.corr()
red_dataset_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
red_dataset_corrnout = red_dataset_nout.corr()
red_dataset_corrnout
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.266585     0.671423
# volatile acidity          -0.266585          1.000000    -0.561747
# citric acid                0.671423         -0.561747     1.000000
# residual sugar             0.171590          0.054465     0.167057
# chlorides                  0.203500          0.104259     0.098305
# free sulfur dioxide       -0.153813          0.002832    -0.055754
# total sulfur dioxide      -0.111438          0.098755     0.006998
# density                    0.656429          0.008294     0.366540
# pH                        -0.667669          0.225051    -0.540366
# sulphates                  0.197527         -0.325177     0.318681
# alcohol                   -0.055544         -0.210089     0.124550
# quality                    0.122331         -0.371854     0.232439
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.171590   0.203500            -0.153813
# volatile acidity            0.054465   0.104259             0.002832
# citric acid                 0.167057   0.098305            -0.055754
# residual sugar              1.000000   0.147925            -0.010520
# chlorides                   0.147925   1.000000            -0.082068
# free sulfur dioxide        -0.010520  -0.082068             1.000000
# total sulfur dioxide        0.099316   0.062577             0.661388
# density                     0.349822   0.331262            -0.037019
# pH                         -0.063717  -0.187140             0.082589
# sulphates                   0.074006   0.050514             0.035082
# alcohol                     0.136489  -0.245763            -0.066852
# quality                     0.034226  -0.148301            -0.046805
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.111438  0.656429 -0.667669   0.197527
# volatile acidity                  0.098755  0.008294  0.225051  -0.325177
# citric acid                       0.006998  0.366540 -0.540366   0.318681
# residual sugar                    0.099316  0.349822 -0.063717   0.074006
# chlorides                         0.062577  0.331262 -0.187140   0.050514
# free sulfur dioxide               0.661388 -0.037019  0.082589   0.035082
# total sulfur dioxide              1.000000  0.116349 -0.045700  -0.042959
# density                           0.116349  1.000000 -0.317774   0.139652
# pH                               -0.045700 -0.317774  1.000000  -0.075071
# sulphates                        -0.042959  0.139652 -0.075071   1.000000
# alcohol                          -0.249369 -0.482217  0.159045   0.179030
# quality                          -0.206907 -0.165710 -0.069041   0.356937
#
#                        alcohol   quality
# fixed acidity        -0.055544  0.122331
# volatile acidity     -0.210089 -0.371854
# citric acid           0.124550  0.232439
# residual sugar        0.136489  0.034226
# chlorides            -0.245763 -0.148301
# free sulfur dioxide  -0.066852 -0.046805
# total sulfur dioxide -0.249369 -0.206907
# density              -0.482217 -0.165710
# pH                    0.159045 -0.069041
# sulphates             0.179030  0.356937
# alcohol               1.000000  0.476305
# quality               0.476305  1.000000

# %%
#comparison with dataset contaigning outliers
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(red_dataset_corrnout, dtype=bool)
mask[np.triu_indices_from(mask)] = True
red_dataset_corrnout[mask] = np.nan
(red_dataset_corrnout
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col0 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col0 {
#             background-color:  #e7745b;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col1 {
#             background-color:  #82a6fb;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col0 {
#             background-color:  #efcebd;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col1 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col2 {
#             background-color:  #efcebd;
#             color:  #000000;
#             : ;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_dd4c9968_3e18_11ec_bd60_c8ff2899f7f1row3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:

# %%
mask = np.zeros_like(red_dataset_corrnout, dtype=bool)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 10))
    ax = sns.heatmap(red_dataset_corrnout, mask=mask, vmax=.3, square=True)

# %%
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(red_dataset_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
red_dataset_corr[mask] = np.nan
(red_dataset_corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col0 {
#             background-color:  #b7cff9;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col0 {
#             background-color:  #e7745b;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col0 {
#             background-color:  #ead4c8;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col1 {
#             background-color:  #dddcdc;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col2 {
#             background-color:  #edd1c2;
#             color:  #000000;
#             : ;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_ddd720d4_3e18_11ec_9cfc_c8ff2899f7f1row3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:

# %%
mask = np.zeros_like(red_dataset_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 10))
    ax = sns.heatmap(red_dataset_corr, mask=mask, vmax=.3, square=True)

# %%
#import seaborn as sns

# %%
#sns.distplot(red_dataset['fixed acidity'])

# %% [markdown]
# ## White analysis

# %%
white_dataset = pd.read_csv(r'C:\Users\giovanni\Desktop\datasets\wine_quality\winequality-white.csv', sep=';')
white_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
white_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white_dataset.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
white_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white_dataset_nout = replace_outliers(white_dataset)
white_dataset_nout
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
summary_dataset_white = summary_table(white_dataset)
summary_dataset_white
# Out:
#                             mean     median     variance  standard_deviation  \
# fixed acidity           6.854788    6.80000     0.711968            0.843782
# volatile acidity        0.278241    0.26000     0.010157            0.100784
# citric acid             0.334192    0.32000     0.014643            0.121007
# residual sugar          6.391415    5.20000    25.720518            5.071540
# chlorides               0.045772    0.04300     0.000477            0.021846
# free sulfur dioxide    35.308085   34.00000   289.183667           17.005401
# total sulfur dioxide  138.360657  134.00000  1805.716751           42.493726
# density                 0.994027    0.99374     0.000009            0.002991
# pH                      3.188267    3.18000     0.022797            0.150985
# sulphates               0.489847    0.47000     0.013022            0.114114
# alcohol                10.514267   10.40000     1.514118            1.230495
# quality                 5.877909    6.00000     0.784196            0.885548
#
#                       outliers_number  \
# fixed acidity                      46
# volatile acidity                   81
# citric acid                        85
# residual sugar                      9
# chlorides                         102
# free sulfur dioxide                32
# total sulfur dioxide               12
# density                             3
# pH                                 32
# sulphates                          48
# alcohol                             0
# quality                            25
#
#                                                         outliers_values
# fixed acidity         [9.8, 9.8, 10.2, 10.0, 10.3, 9.4, 9.8, 9.6, 9....
# volatile acidity      [0.66, 0.66, 0.67, 0.595, 0.67, 0.685, 0.64, 0...
# citric acid           [0.88, 0.7, 0.7, 0.71, 0.72, 0.7, 1.66, 1.0, 0...
# residual sugar        [22.0, 22.0, 23.5, 31.6, 31.6, 65.8, 26.05, 26...
# chlorides             [0.172, 0.17300000000000001, 0.147, 0.2, 0.196...
# free sulfur dioxide   [131.0, 87.0, 87.0, 122.5, 88.0, 118.5, 96.0, ...
# total sulfur dioxide  [272.0, 313.0, 366.5, 307.5, 344.0, 282.0, 303...
# density                                       [1.0103, 1.0103, 1.03898]
# pH                    [3.69, 3.72, 3.72, 3.72, 3.66, 3.82, 3.81, 3.6...
# sulphates             [0.84, 0.85, 0.85, 0.96, 0.97, 0.95, 0.95, 0.9...
# alcohol                                                              []
# quality               [3, 3, 3, 3, 3, 9, 9, 9, 3, 9, 3, 3, 3, 3, 9, ...

# %%
summary_dataset_white_nout = summary_table(white_dataset_nout)
summary_dataset_white_nout
# Out:
#                             mean     median     variance  standard_deviation  \
# fixed acidity           6.830802    6.80000     0.625810            0.791081
# volatile acidity        0.271535    0.26000     0.007438            0.086243
# citric acid             0.326273    0.31000     0.010981            0.104789
# residual sugar          6.347709    5.20000    24.412729            4.940924
# chlorides               0.043229    0.04300     0.000138            0.011738
# free sulfur dioxide    34.811139   34.00000   244.999165           15.652449
# total sulfur dioxide  138.042878  134.00000  1731.188552           41.607554
# density                 0.994012    0.99373     0.000008            0.002903
# pH                      3.184994    3.18000     0.021090            0.145224
# sulphates               0.485569    0.47000     0.011250            0.106064
# alcohol                10.514267   10.40000     1.514118            1.230495
# quality                 5.877909    6.00000     0.784196            0.885548
#
#                       outliers_number  \
# fixed acidity                       6
# volatile acidity                   47
# citric acid                        60
# residual sugar                      0
# chlorides                          70
# free sulfur dioxide                11
# total sulfur dioxide                0
# density                             2
# pH                                  9
# sulphates                          20
# alcohol                             0
# quality                            25
#
#                                                         outliers_values
# fixed acidity                            [9.3, 9.3, 9.3, 4.4, 4.4, 4.4]
# volatile acidity      [0.54, 0.54, 0.57, 0.58, 0.58, 0.55, 0.55, 0.5...
# citric acid           [0.66, 0.66, 0.0, 0.67, 0.67, 0.0, 0.0, 0.65, ...
# residual sugar                                                       []
# chlorides             [0.08, 0.092, 0.08199999999999999, 0.092, 0.08...
# free sulfur dioxide   [82.0, 82.5, 83.0, 83.0, 82.0, 83.0, 83.0, 85....
# total sulfur dioxide                                                 []
# density                                              [1.00295, 1.00295]
# pH                    [3.63, 3.64, 3.64, 2.74, 3.63, 3.63, 3.63, 3.6...
# sulphates             [0.82, 0.82, 0.82, 0.82, 0.81, 0.81, 0.82, 0.8...
# alcohol                                                              []
# quality               [3, 3, 3, 3, 3, 9, 9, 9, 3, 9, 3, 3, 3, 3, 9, ...

# %%
white_dataset_corr = white_dataset.corr()
white_dataset_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.120881 -0.113663
# volatile acidity      0.067718 -0.194723
# citric acid          -0.075729 -0.009209
# residual sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free sulfur dioxide  -0.250104  0.008158
# total sulfur dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
white_dataset_corrnout = white_dataset_nout.corr()
white_dataset_corrnout
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.029153     0.287724
# volatile acidity          -0.029153          1.000000    -0.146305
# citric acid                0.287724         -0.146305     1.000000
# residual sugar             0.104322          0.067318     0.078728
# chlorides                  0.081936          0.017303     0.025438
# free sulfur dioxide       -0.024599         -0.078260     0.118116
# total sulfur dioxide       0.092800          0.105431     0.111315
# density                    0.267256          0.003896     0.138413
# pH                        -0.399896         -0.041136    -0.163869
# sulphates                 -0.008135         -0.038027     0.066043
# alcohol                   -0.117198          0.077662    -0.066624
# quality                   -0.090050         -0.152413     0.017922
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.104322   0.081936            -0.024599
# volatile acidity            0.067318   0.017303            -0.078260
# citric acid                 0.078728   0.025438             0.118116
# residual sugar              1.000000   0.236711             0.342497
# chlorides                   0.236711   1.000000             0.121863
# free sulfur dioxide         0.342497   0.121863             1.000000
# total sulfur dioxide        0.416236   0.324294             0.612581
# density                     0.831054   0.451993             0.335740
# pH                         -0.193324  -0.039810            -0.007493
# sulphates                  -0.012172   0.078364             0.067152
# alcohol                    -0.461488  -0.511873            -0.265333
# quality                    -0.098487  -0.286542             0.034395
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.092800  0.267256 -0.399896  -0.008135
# volatile acidity                  0.105431  0.003896 -0.041136  -0.038027
# citric acid                       0.111315  0.138413 -0.163869   0.066043
# residual sugar                    0.416236  0.831054 -0.193324  -0.012172
# chlorides                         0.324294  0.451993 -0.039810   0.078364
# free sulfur dioxide               0.612581  0.335740 -0.007493   0.067152
# total sulfur dioxide              1.000000  0.549509 -0.000592   0.154952
# density                           0.549509  1.000000 -0.105870   0.100135
# pH                               -0.000592 -0.105870  1.000000   0.150209
# sulphates                         0.154952  0.100135  0.150209   1.000000
# alcohol                          -0.455732 -0.804152  0.124223  -0.047083
# quality                          -0.165682 -0.317232  0.107379   0.033781
#
#                        alcohol   quality
# fixed acidity        -0.117198 -0.090050
# volatile acidity      0.077662 -0.152413
# citric acid          -0.066624  0.017922
# residual sugar       -0.461488 -0.098487
# chlorides            -0.511873 -0.286542
# free sulfur dioxide  -0.265333  0.034395
# total sulfur dioxide -0.455732 -0.165682
# density              -0.804152 -0.317232
# pH                    0.124223  0.107379
# sulphates            -0.047083  0.033781
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
#comparison with dataset contaigning outliers
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
#mask = np.zeros_like(white_dataset_corrnout, dtype=bool)
#mask[np.triu_indices_from(mask)] = True
#white_dataset_corrnout[mask] = np.nan
#(white_dataset_corrnout
# .style
# .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
# .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
# .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)

# %%
mask = np.zeros_like(white_dataset_corrnout)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(white_dataset_corrnout, mask=mask, vmax=.3, square=True)

# %%
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(white_dataset_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
white_dataset_corr[mask] = np.nan
(white_dataset_corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col0 {
#             background-color:  #dadce0;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col0 {
#             background-color:  #f6bea4;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col1 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col1 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col2 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#             : ;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_f00acdde_3e18_11ec_9306_c8ff2899f7f1row3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:

# %% [markdown]
# ## Trying to analyse everything together

# %%
all_wines_nout = pd.concat([red_dataset_nout, white_dataset_nout])
all_wines_nout
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [6497 rows x 12 columns]

# %%
all_wines_nout_summary = summary_table(all_wines_nout)
all_wines_nout_summary
# Out:
#                             mean     median     variance  standard_deviation  \
# fixed acidity           7.185673    7.00000     1.528837            1.236461
# volatile acidity        0.334018    0.29000     0.024629            0.156936
# citric acid             0.312376    0.31000     0.018201            0.134912
# residual sugar          5.387612    3.00000    21.545644            4.641729
# chlorides               0.052780    0.04700     0.000513            0.022647
# free sulfur dioxide    30.044234   29.00000   276.938832           16.641479
# total sulfur dioxide  115.338408  118.00000  3124.663030           55.898685
# density                 0.994675    0.99488     0.000009            0.002916
# pH                      3.215530    3.21000     0.024221            0.155630
# sulphates               0.524671    0.50000     0.017661            0.132896
# alcohol                10.487337   10.30000     1.407805            1.186509
# quality                 5.818378    6.00000     0.762457            0.873188
#
#                       outliers_number  \
# fixed acidity                     134
# volatile acidity                   94
# citric acid                        14
# residual sugar                     26
# chlorides                          69
# free sulfur dioxide                19
# total sulfur dioxide                0
# density                             0
# pH                                 15
# sulphates                          62
# alcohol                             2
# quality                            35
#
#                                                         outliers_values
# fixed acidity         [11.2, 11.5, 12.8, 12.8, 11.0, 11.6, 12.0, 11....
# volatile acidity      [0.88, 0.935, 1.02, 0.9, 1.04, 0.95, 0.885, 0....
# citric acid           [0.74, 0.74, 0.76, 0.79, 0.76, 0.73, 0.72, 0.7...
# residual sugar        [20.7, 20.7, 19.45, 19.45, 19.8, 20.8, 19.45, ...
# chlorides             [0.17600000000000002, 0.17, 0.172, 0.122, 0.17...
# free sulfur dioxide   [81.0, 82.0, 82.5, 83.0, 83.0, 81.0, 80.0, 82....
# total sulfur dioxide                                                 []
# density                                                              []
# pH                    [3.75, 3.69, 3.69, 3.74, 3.72, 3.71, 3.69, 3.6...
# sulphates             [0.93, 1.08, 0.95, 1.12, 1.14, 0.93, 0.93, 1.0...
# alcohol                                                   [14.2, 14.05]
# quality               [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...

# %%
all_wines_corrnout = all_wines_nout.corr()
all_wines_corrnout
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.245210     0.332836
# volatile acidity           0.245210          1.000000    -0.393544
# citric acid                0.332836         -0.393544     1.000000
# residual sugar            -0.120060         -0.221645     0.127166
# chlorides                  0.456508          0.544598    -0.096056
# free sulfur dioxide       -0.293378         -0.380907     0.143112
# total sulfur dioxide      -0.345051         -0.449819     0.179853
# density                    0.459985          0.282457     0.085709
# pH                        -0.211616          0.279690    -0.336406
# sulphates                  0.319453          0.258850     0.048976
# alcohol                   -0.095157         -0.044089     0.006055
# quality                   -0.069052         -0.242557     0.109258
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.120060   0.456508            -0.293378
# volatile acidity           -0.221645   0.544598            -0.380907
# citric acid                 0.127166  -0.096056             0.143112
# residual sugar              1.000000  -0.165078             0.443590
# chlorides                  -0.165078   1.000000            -0.338230
# free sulfur dioxide         0.443590  -0.338230             1.000000
# total sulfur dioxide        0.512840  -0.423408             0.733853
# density                     0.531675   0.524849             0.033565
# pH                         -0.273849   0.198049            -0.166527
# sulphates                  -0.192940   0.415058            -0.216784
# alcohol                    -0.366682  -0.291359            -0.184439
# quality                    -0.035774  -0.236138             0.078997
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.345051  0.459985 -0.211616   0.319453
# volatile acidity                 -0.449819  0.282457  0.279690   0.258850
# citric acid                       0.179853  0.085709 -0.336406   0.048976
# residual sugar                    0.512840  0.531675 -0.273849  -0.192940
# chlorides                        -0.423408  0.524849  0.198049   0.415058
# free sulfur dioxide               0.733853  0.033565 -0.166527  -0.216784
# total sulfur dioxide              1.000000  0.031511 -0.252486  -0.306128
# density                           0.031511  1.000000  0.020990   0.285919
# pH                               -0.252486  0.020990  1.000000   0.250566
# sulphates                        -0.306128  0.285919  0.250566   1.000000
# alcohol                          -0.266737 -0.706524  0.108664  -0.007114
# quality                          -0.033931 -0.313046  0.020481   0.043901
#
#                        alcohol   quality
# fixed acidity        -0.095157 -0.069052
# volatile acidity     -0.044089 -0.242557
# citric acid           0.006055  0.109258
# residual sugar       -0.366682 -0.035774
# chlorides            -0.291359 -0.236138
# free sulfur dioxide  -0.184439  0.078997
# total sulfur dioxide -0.266737 -0.033931
# density              -0.706524 -0.313046
# pH                    0.108664  0.020481
# sulphates            -0.007114  0.043901
# alcohol               1.000000  0.444670
# quality               0.444670  1.000000

# %%
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(all_wines_corrnout, dtype=bool)
mask[np.triu_indices_from(mask)] = True
all_wines_corrnout[mask] = np.nan
(all_wines_corrnout
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col0 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col0 {
#             background-color:  #f7b89c;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col1 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col2 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#             : ;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_2c4b2b6e_3e19_11ec_83f2_c8ff2899f7f1row3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:

# %%
all_wines = pd.concat([red_dataset, white_dataset])
all_wines_summary = summary_table(all_wines_nout)
all_wines_summary
# Out:
#                             mean     median     variance  standard_deviation  \
# fixed acidity           7.185673    7.00000     1.528837            1.236461
# volatile acidity        0.334018    0.29000     0.024629            0.156936
# citric acid             0.312376    0.31000     0.018201            0.134912
# residual sugar          5.387612    3.00000    21.545644            4.641729
# chlorides               0.052780    0.04700     0.000513            0.022647
# free sulfur dioxide    30.044234   29.00000   276.938832           16.641479
# total sulfur dioxide  115.338408  118.00000  3124.663030           55.898685
# density                 0.994675    0.99488     0.000009            0.002916
# pH                      3.215530    3.21000     0.024221            0.155630
# sulphates               0.524671    0.50000     0.017661            0.132896
# alcohol                10.487337   10.30000     1.407805            1.186509
# quality                 5.818378    6.00000     0.762457            0.873188
#
#                       outliers_number  \
# fixed acidity                     134
# volatile acidity                   94
# citric acid                        14
# residual sugar                     26
# chlorides                          69
# free sulfur dioxide                19
# total sulfur dioxide                0
# density                             0
# pH                                 15
# sulphates                          62
# alcohol                             2
# quality                            35
#
#                                                         outliers_values
# fixed acidity         [11.2, 11.5, 12.8, 12.8, 11.0, 11.6, 12.0, 11....
# volatile acidity      [0.88, 0.935, 1.02, 0.9, 1.04, 0.95, 0.885, 0....
# citric acid           [0.74, 0.74, 0.76, 0.79, 0.76, 0.73, 0.72, 0.7...
# residual sugar        [20.7, 20.7, 19.45, 19.45, 19.8, 20.8, 19.45, ...
# chlorides             [0.17600000000000002, 0.17, 0.172, 0.122, 0.17...
# free sulfur dioxide   [81.0, 82.0, 82.5, 83.0, 83.0, 81.0, 80.0, 82....
# total sulfur dioxide                                                 []
# density                                                              []
# pH                    [3.75, 3.69, 3.69, 3.74, 3.72, 3.71, 3.69, 3.6...
# sulphates             [0.93, 1.08, 0.95, 1.12, 1.14, 0.93, 0.93, 1.0...
# alcohol                                                   [14.2, 14.05]
# quality               [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...

# %%
all_wines_corr = all_wines.corr()
all_wines_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
#
#                        alcohol   quality
# fixed acidity        -0.095452 -0.076743
# volatile acidity     -0.037640 -0.265699
# citric acid          -0.010493  0.085532
# residual sugar       -0.359415 -0.036980
# chlorides            -0.256916 -0.200666
# free sulfur dioxide  -0.179838  0.055463
# total sulfur dioxide -0.265740 -0.041385
# density              -0.686745 -0.305858
# pH                    0.121248  0.019506
# sulphates            -0.003029  0.038485
# alcohol               1.000000  0.444319
# quality               0.444319  1.000000

# %%
#correlation directly on dataframe
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(all_wines_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
all_wines_corr[mask] = np.nan
(all_wines_corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
#transposed_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col0 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row1_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col0 {
#             background-color:  #f7b99e;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col1 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col0 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col1 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col2 {
#             background-color:  #edd1c2;
#             color:  #000000;
#             : ;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #f1f1f1;
#         }    #T_1313985c_3e1a_11ec_962a_c8ff2899f7f1row3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:

# %%
lista_colonne = list(all_wines_nout)
for c in lista_colonne:
    plt.figure(figsize=(20,10))
    sns.distplot(all_wines_nout[c])
    plt.savefig(r'C:\Users\giovanni\Desktop\datasets\wine_quality\plots\all_wines_'+c)

# %% [markdown]
# ## colorare diversamente gli histogrammi
